# %%
import os.path as osp
from collections import Counter
from pprint import pprint

import numpy as np
import pandas as pd

import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

sns.set_theme(style="whitegrid")
sns.set_theme(rc={'figure.figsize':(17, 9)})

# %%
DATA_PATH = osp.join('data/data_kion')

users_df = pd.read_csv(osp.join(DATA_PATH, 'users.csv'))
items_df = pd.read_csv(osp.join(DATA_PATH, 'items.csv'))
interactions_df = pd.read_csv(osp.join(DATA_PATH, 'interactions_df.csv'), parse_dates=['last_watch_dt'])

# %% [markdown]
# # EDA

# %% [markdown]
# ## Users

# %%
users_df.head()
# Out:
#    user_id        age        income sex  kids_flg
# 0   973171  age_25_34  income_60_90   М         1
# 1   962099  age_18_24  income_20_40   М         0
# 2  1047345  age_45_54  income_40_60   Ж         0
# 3   721985  age_45_54  income_20_40   Ж         0
# 4   704055  age_35_44  income_60_90   Ж         0

# %%
users_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840197 entries, 0 to 840196
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   840197 non-null  int64
#  1   age       826102 non-null  object
#  2   income    825421 non-null  object
#  3   sex       826366 non-null  object
#  4   kids_flg  840197 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 32.1+ MB

# %%
users_df.nunique()
# Out:
# user_id     840197
# age              6
# income           6
# sex              2
# kids_flg         2
# dtype: int64

# %% [markdown]
# ### Preprocess

# %% [markdown]
# #### Age

# %%
users_df['age'] = users_df['age'].fillna('age_unknown')

# %%
sorted_age_categories = sorted(users_df['age'].unique(), key=lambda s: float(s.split('_')[1] if len(s.split('_')) == 3 else np.inf))
pd.Categorical(users_df['age'], categories=sorted_age_categories, ordered=True).value_counts().sort_index().plot(kind='bar');

# %%
users_df['age'].value_counts()
# Out:
# age
# age_25_34      233926
# age_35_44      207043
# age_45_54      135925
# age_18_24      127672
# age_55_64       75265
# age_65_inf      46271
# age_unknown     14095
# Name: count, dtype: int64

# %%
users_df['age'] = users_df['age'].astype('category')

# %% [markdown]
# #### Income

# %%
users_df['income'] = users_df['income'].fillna('income_unknown')

# %%
sorted_income_categories = sorted(users_df['income'].unique(), key=lambda s: float(s.split('_')[1] if len(s.split('_')) == 3 else np.inf))
pd.Categorical(users_df['income'], categories=sorted_income_categories, ordered=True).value_counts().sort_index().plot(kind='bar');

# %%
users_df['income'].value_counts()
# Out:
# income
# income_20_40      471519
# income_40_60      248330
# income_60_90       68674
# income_0_20        21836
# income_unknown     14776
# income_90_150      13985
# income_150_inf      1077
# Name: count, dtype: int64

# %%
users_df['income'] = users_df['income'].astype('category')

# %% [markdown]
# #### Sex

# %%
users_df['sex'].value_counts()
# Out:
# sex
# Ж    425270
# М    401096
# Name: count, dtype: int64

# %%
users_df['sex'] = users_df['sex'].fillna('sex_unknown')

# %%
users_df.loc[users_df.sex == 'М', 'sex'] = 'M'
users_df.loc[users_df.sex == 'Ж', 'sex'] = 'F'

# %%
users_df['sex'].value_counts()
# Out:
# sex
# F              425270
# M              401096
# sex_unknown     13831
# Name: count, dtype: int64

# %%
users_df['sex'] = users_df['sex'].astype('category')

# %% [markdown]
# #### kids_flg

# %%
users_df['kids_flg'].value_counts()
# Out:
# kids_flg
# 0    587209
# 1    252988
# Name: count, dtype: int64

# %%
users_df['kids_flg'] = users_df['kids_flg'].astype('bool')
users_df['kids_flg'].value_counts()
# Out:
# kids_flg
# False    587209
# True     252988
# Name: count, dtype: int64

# %% [markdown]
# #### Duplicates check

# %%
users_df.duplicated(subset=['user_id'], keep=False).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Result

# %%
users_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840197 entries, 0 to 840196
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   840197 non-null  int64
#  1   age       840197 non-null  category
#  2   income    840197 non-null  category
#  3   sex       840197 non-null  category
#  4   kids_flg  840197 non-null  bool
# dtypes: bool(1), category(3), int64(1)
# memory usage: 9.6 MB

# %% [markdown]
# ## Items

# %%
items_df
# Out:
#        item_id content_type                 title      title_orig  \
# 0        10711         film        Поговори с ней  Hable con ella
# 1         2508         film           Голые перцы    Search Party
# 2        10716         film      Тактическая сила  Tactical Force
# 3         7868         film                45 лет        45 Years
# 4        16268         film  Все решает мгновение             NaN
# ...        ...          ...                   ...             ...
# 15958     6443       series         Полярный круг   Arctic Circle
# 15959     2367       series               Надежда             NaN
# 15960    10632       series                Сговор          Hassel
# 15961     4538       series          Среди камней      Darklands
# 15962     3206       series                  Гоша             NaN
#
#        release_year                                            genres  \
# 0            2002.0           драмы, зарубежные, детективы, мелодрамы
# 1            2014.0                  зарубежные, приключения, комедии
# 2            2011.0  криминал, зарубежные, триллеры, боевики, комедии
# 3            2015.0                      драмы, зарубежные, мелодрамы
# 4            1978.0                драмы, спорт, советские, мелодрамы
# ...             ...                                               ...
# 15958        2018.0                         драмы, триллеры, криминал
# 15959        2020.0                                    драмы, боевики
# 15960        2017.0                         драмы, триллеры, криминал
# 15961        2019.0                            драмы, спорт, криминал
# 15962        2019.0                                           комедии
#
#                  countries  for_kids  age_rating   studios  \
# 0                  Испания       NaN        16.0       NaN
# 1                      США       NaN        16.0       NaN
# 2                   Канада       NaN        16.0       NaN
# 3           Великобритания       NaN        16.0       NaN
# 4                     СССР       NaN        12.0  Ленфильм
# ...                    ...       ...         ...       ...
# 15958  Финляндия, Германия       NaN        16.0       NaN
# 15959               Россия       0.0        18.0       NaN
# 15960               Россия       0.0        18.0       NaN
# 15961               Россия       0.0        18.0       NaN
# 15962               Россия       0.0        16.0       NaN
#
#                                    directors  \
# 0                           Педро Альмодовар
# 1                             Скот Армстронг
# 2                           Адам П. Калтраро
# 3                                  Эндрю Хэй
# 4                           Виктор Садовский
# ...                                      ...
# 15958                          Ханну Салонен
# 15959                         Елена Хазанова
# 15960  Эшреф Рейбрук, Амир Камдин, Эрик Эгер
# 15961          Марк О’Коннор, Конор МакМахон
# 15962                         Михаил Миронов
#
#                                                   actors  \
# 0      Адольфо Фернандес, Ана Фернандес, Дарио Гранди...
# 1      Адам Палли, Брайан Хаски, Дж.Б. Смув, Джейсон ...
# 2      Адриан Холмс, Даррен Шалави, Джерри Вассерман,...
# 3      Александра Риддлстон-Барретт, Джеральдин Джейм...
# 4      Александр Абдулов, Александр Демьяненко, Алекс...
# ...                                                  ...
# 15958  Иина Куустонен, Максимилиан Брюкнер, Пихла Вии...
# 15959  Виктория Исакова, Александр Кузьмин, Алексей М...
# 15960  Ола Рапас, Алиетт Офейм, Уильма Лиден, Шанти Р...
# 15961  Дэйн Уайт О’Хара, Томас Кэйн-Бирн, Джудит Родд...
# 15962                 Мкртыч Арзуманян, Виктория Рунцова
#
#                                              description  \
# 0      Мелодрама легендарного Педро Альмодовара «Пого...
# 1      Уморительная современная комедия на популярную...
# 2      Профессиональный рестлер Стив Остин («Все или ...
# 3      Шарлотта Рэмплинг, Том Кортни, Джеральдин Джей...
# 4      Расчетливая чаровница из советского кинохита «...
# ...                                                  ...
# 15958  Во время погони за браконьерами по лесу, сотру...
# 15959  Оригинальный киносериал от создателей «Бывших»...
# 15960  Криминальная драма по мотивам романов о шведск...
# 15961  Семнадцатилетний Дэмиен мечтает вырваться за п...
# 15962  Добродушный Гоша не может выйти из дома, чтобы...
#
#                                                 keywords
# 0      Поговори, ней, 2002, Испания, друзья, любовь, ...
# 1      Голые, перцы, 2014, США, друзья, свадьбы, прео...
# 2      Тактическая, сила, 2011, Канада, бандиты, ганг...
# 3      45, лет, 2015, Великобритания, брак, жизнь, лю...
# 4      Все, решает, мгновение, 1978, СССР, сильные, ж...
# ...                                                  ...
# 15958  убийство, вирус, расследование преступления, н...
# 15959                              Надежда, 2020, Россия
# 15960                               Сговор, 2017, Россия
# 15961                        Среди, камней, 2019, Россия
# 15962                                 Гоша, 2019, Россия
#
# [15963 rows x 14 columns]

# %%
items_df.nunique()
# Out:
# item_id         15963
# content_type        2
# title           15293
# title_orig      10575
# release_year      105
# genres           2771
# countries         687
# for_kids            2
# age_rating          6
# studios            38
# directors        7973
# actors          12996
# description     15619
# keywords        15492
# dtype: int64

# %%
items_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15963 entries, 0 to 15962
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   item_id       15963 non-null  int64
#  1   content_type  15963 non-null  object
#  2   title         15963 non-null  object
#  3   title_orig    11218 non-null  object
#  4   release_year  15865 non-null  float64
#  5   genres        15963 non-null  object
#  6   countries     15926 non-null  object
#  7   for_kids      566 non-null    float64
#  8   age_rating    15961 non-null  float64
#  9   studios       1065 non-null   object
#  10  directors     14454 non-null  object
#  11  actors        13344 non-null  object
#  12  description   15961 non-null  object
#  13  keywords      15540 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Preprocess

# %% [markdown]
# #### content_type

# %%
items_df['content_type'].value_counts()
# Out:
# content_type
# film      12002
# series     3961
# Name: count, dtype: int64

# %%
items_df['content_type'] = items_df['content_type'].astype('category')

# %% [markdown]
# #### title

# %%
items_df['title'].head()
# Out:
# 0          Поговори с ней
# 1             Голые перцы
# 2        Тактическая сила
# 3                  45 лет
# 4    Все решает мгновение
# Name: title, dtype: object

# %%
items_df.duplicated(subset=['title']).sum()
# Out:
# np.int64(670)

# %%
items_df['title'] = items_df['title'].str.lower()

# %% [markdown]
# #### title_orig

# %%
items_df['title_orig'].head()
# Out:
# 0    Hable con ella
# 1      Search Party
# 2    Tactical Force
# 3          45 Years
# 4               NaN
# Name: title_orig, dtype: object

# %%
items_df[items_df['title_orig'].isna()]['countries'].value_counts().head()
# Out:
# countries
# Россия            2899
# СССР               918
# Украина            240
# США                101
# Великобритания      87
# Name: count, dtype: int64

# %%
items_df[(items_df['title_orig'].isna()) & (items_df['countries'] == 'Россия')]
# Out:
#        item_id content_type  \
# 5          854         film
# 9         8604         film
# 11       15056         film
# 19       15261         film
# 25        7325         film
# ...        ...          ...
# 15948     1830       series
# 15949    15986       series
# 15951     4914       series
# 15959     2367       series
# 15962     3206       series
#
#                                                    title title_orig  \
# 5                                              северо-юг        NaN
# 9                                         третья попытка        NaN
# 11                                        последний шанс        NaN
# 19     спящая красавица. легенда двух королевств: лед...        NaN
# 25                                        вдовий пароход        NaN
# ...                                                  ...        ...
# 15948                    секреты ежедневного фэйсфитнеса        NaN
# 15949                                           новаторы        NaN
# 15951                                        таёжник гил        NaN
# 15959                                            надежда        NaN
# 15962                                               гоша        NaN
#
#        release_year                                             genres  \
# 5            2015.0                                     драмы, русские
# 9            2013.0                                 русские, мелодрамы
# 11           2018.0                                   боевики, русские
# 19           2020.0  русские, сказки, фильмы-спектакли, мюзиклы, се...
# 25           2010.0                                     драмы, русские
# ...             ...                                                ...
# 15948           NaN                                             фитнес
# 15949        2010.0  русские, для детей, сериалы, хочу всё знать, р...
# 15951        2014.0                                           no_genre
# 15959        2020.0                                     драмы, боевики
# 15962        2019.0                                            комедии
#
#       countries  for_kids  age_rating studios  \
# 5        Россия       NaN        16.0     NaN
# 9        Россия       NaN        12.0     NaN
# 11       Россия       NaN        16.0     NaN
# 19       Россия       NaN         0.0     NaN
# 25       Россия       NaN        16.0     NaN
# ...         ...       ...         ...     ...
# 15948    Россия       NaN         6.0     NaN
# 15949    Россия       NaN         6.0     NaN
# 15951    Россия       NaN        12.0     NaN
# 15959    Россия       0.0        18.0     NaN
# 15962    Россия       0.0        16.0     NaN
#
#                                             directors  \
# 5                                        Юрий Грубник
# 9                                      Игорь Мужжухин
# 11                                     Михаил Погосов
# 19     Игорь Оршуляк, Татьяна Навка, Юрий Антизерский
# 25                                    Станислав Митин
# ...                                               ...
# 15948                                             NaN
# 15949                                  Алексей Штыхин
# 15951                                             NaN
# 15959                                  Елена Хазанова
# 15962                                  Михаил Миронов
#
#                                                   actors  \
# 5      Алексей Воронин, Алексей Мурашов, Алена Алинин...
# 9      Александр Асташенок, Александр Пашков, Андрей ...
# 11     Александр Носик, Алексей Кравченко, Василий Шл...
# 19     Алина Загитова, Маргарита Дробязко, Ондржей Го...
# 25     Александр Пашков, Вадим Померанцев, Галина Пет...
# ...                                                  ...
# 15948                                                NaN
# 15949  Александр Пинегин, Дмитрий Филимонов, Лариса Б...
# 15951                                                NaN
# 15959  Виктория Исакова, Александр Кузьмин, Алексей М...
# 15962                 Мкртыч Арзуманян, Виктория Рунцова
#
#                                              description  \
# 5      Авторский фильм молодого режиссера Юрия Грубни...
# 9      Екатерина Рябова, Александр Асташенок и Алекса...
# 11     Несколько лет назад Андрей Борисов оставил слу...
# 19     Ледовое шоу-феерия Татьяны Навки, вдохновленно...
# 25     Телевизионный фильм Станислава Митина по однои...
# ...                                                  ...
# 15948  Ежедневный уход за лицом изменит вашу жизнь. П...
# 15949  Отечественный познавательный мультсериал о пут...
# 15951  Автор проекта работает инженером-таксатором на...
# 15959  Оригинальный киносериал от создателей «Бывших»...
# 15962  Добродушный Гоша не может выйти из дома, чтобы...
#
#                                                 keywords
# 5      Северо-Юг, 2015, Россия, бандиты, гангстеры, б...
# 9      Третья, попытка, 2013, Россия, любовь, измена,...
# 11     Последний, шанс, 2018, Россия, бандиты, гангст...
# 19     Спящая, красавица, Легенда, двух, королевств, ...
# 25                         Вдовий, пароход, 2010, Россия
# ...                                                  ...
# 15948  Секреты, ежедневного, фэйсфитнеса, Россия, спо...
# 15949  Новаторы, 2010, Россия, друзья, космос, наука,...
# 15951                         Таёжник, ГИЛ, 2014, Россия
# 15959                              Надежда, 2020, Россия
# 15962                                 Гоша, 2019, Россия
#
# [2899 rows x 14 columns]

# %%
items_df['title_orig'] = items_df['title_orig'].fillna('None')

# %%
items_df.duplicated(subset=['title_orig']).sum()
# Out:
# np.int64(5387)

# %%
items_df.duplicated(subset=['title', 'title_orig']).sum()
# Out:
# np.int64(192)

# %% [markdown]
# #### release_year

# %%
items_df['release_year'].hist(bins=40);

# %%
items_df[items_df['release_year'].isna()].head()
# Out:
#      item_id content_type                title title_orig  release_year  \
# 89     10950       series           начни дома       None           NaN
# 294     3901       series         красота лица       None           NaN
# 374    10656       series  медитации для жизни       None           NaN
# 375    11526       series   психология питания       None           NaN
# 572    11532       series           йога старт       None           NaN
#
#             genres countries  for_kids  age_rating studios directors actors  \
# 89          фитнес    Россия       NaN         6.0     NaN       NaN    NaN
# 294         фитнес    Россия       NaN         0.0     NaN       NaN    NaN
# 374         фитнес       NaN       NaN         6.0     NaN       NaN    NaN
# 375  фитнес, спорт       NaN       NaN         6.0     NaN       NaN    NaN
# 572         фитнес    Россия       NaN         6.0     NaN       NaN    NaN
#
#                                            description  \
# 89   Приведи себя в хорошую форму дома с минимальны...
# 294  Motify научит вас простым, но очень эффективны...
# 374  В этой программе собраны 3 базовых урока, на к...
# 375  В программе от Motify ты узнаешь о психологиче...
# 572  Программа от Motify подойдет для любого уровня...
#
#                                               keywords
# 89   Начни, дома, Россия, спорт-фитнес, спорт-трене...
# 294  Красота, лица, 2020, Россия, спорт-фитнес, спо...
# 374  Медитации, для, жизни, спорт-фитнес, спорт-тре...
# 375                                Психология, питания
# 572  Йога, 2020, Россия, спорт-фитнес, спорт-тренер...

# %%
items_df[items_df['release_year'].isna()][['age_rating', 'genres', 'countries']].value_counts()
# Out:
# age_rating  genres                                                 countries
# 6.0         фитнес                                                 Россия              54
# 0.0         футбол                                                 Россия              22
#             фитнес                                                 Россия               5
#             зарубежные, детские песни, развитие, для детей         Республика Корея     1
#             зарубежные, для детей, западные мультфильмы, развитие  Республика Корея     1
# 6.0         фитнес                                                 Великобритания       1
# Name: count, dtype: int64

# %% [markdown]
# Год можно, например, преобразовать к категории следующим способом, если это необходимо

# %%
items_df.loc[items_df['release_year'].isna(), 'release_year'] = 2020.

# %%
items_df.loc[items_df['release_year'] < 1920, 'release_year_cat'] = 'inf_1920'
items_df.loc[items_df['release_year'] >= 2020, 'release_year_cat'] = '2020_inf'

# %%
for i in range (1920, 2020, 10):
    items_df.loc[(items_df['release_year'] >= i) & (items_df['release_year'] < i+10), 'release_year_cat'] = f'{i}_{i+10}'

# %%
items_df['release_year_cat'].value_counts()
# Out:
# release_year_cat
# 2010_2020    8788
# 2020_inf     2276
# 2000_2010    2168
# 1980_1990     745
# 1990_2000     636
# 1970_1980     553
# 1960_1970     342
# 1950_1960     199
# 1940_1950     117
# 1930_1940     104
# 1920_1930      24
# inf_1920       11
# Name: count, dtype: int64

# %%
items_df = items_df.drop(columns=['release_year'])
items_df['release_year_cat'] = items_df['release_year_cat'].astype('category')

# %% [markdown]
# #### genres

# %%
items_df['genres'].value_counts()
# Out:
# genres
# документальное                                          816
# драмы                                                   719
# комедии                                                 564
# для взрослых                                            482
# русские, мелодрамы                                      416
#                                                        ...
# драмы, популярное, семейное, приключения                  1
# приключения, драмы, зарубежные, военные, фантастика       1
# мюзиклы, советские, комедии                               1
# биография, русские, короткометражные, документальное      1
# зарубежные, семейное, фильмы, про животных                1
# Name: count, Length: 2771, dtype: int64

# %%
items_df[items_df['genres'] == 'no_genre']
# Out:
#        item_id content_type  \
# 384      11373       series
# 385       3671       series
# 479      10271       series
# 525         33         film
# 618       1645         film
# ...        ...          ...
# 15711     4014       series
# 15770     4386       series
# 15790    12364         film
# 15834      759       series
# 15951     4914       series
#
#                                                    title  \
# 384                            ирина аллегрова - караоке
# 385                              google диск. знакомство
# 479                                    фабрика - караоке
# 525                                    встречи с учеными
# 618    глеб архангельский. тайм-менеджмент: как заста...
# ...                                                  ...
# 15711                                    tags play theme
# 15770                          светлана лобода - караоке
# 15790  гибкость ног. безопасная подготовка к шпагату....
# 15834                                            amitesh
# 15951                                        таёжник гил
#
#                                               title_orig    genres countries  \
# 384                            Irina Allegrova - karaoke  no_genre    Россия
# 385                              Google Disk. Znakomstvo  no_genre    Россия
# 479                                                 None  no_genre    Россия
# 525                                                 None  no_genre    Россия
# 618    Gleb Arkhangel′skiy. Taym-menedzhment: kak zas...  no_genre    Россия
# ...                                                  ...       ...       ...
# 15711                                               None  no_genre    Россия
# 15770                          Svetlana Loboda - karaoke  no_genre   Украина
# 15790  Gibkost′ nog. Bezopasnaya podgotovka k shpagat...  no_genre    Россия
# 15834                                               None  no_genre    Россия
# 15951                                               None  no_genre    Россия
#
#        for_kids  age_rating studios directors actors  \
# 384         NaN         0.0     NaN       NaN    NaN
# 385         NaN        12.0     NaN       NaN    NaN
# 479         NaN         0.0     NaN       NaN    NaN
# 525         NaN        12.0     NaN       NaN    NaN
# 618         NaN        12.0     NaN       NaN    NaN
# ...         ...         ...     ...       ...    ...
# 15711       NaN        16.0     NaN       NaN    NaN
# 15770       NaN         0.0     NaN       NaN    NaN
# 15790       NaN        12.0     NaN       NaN    NaN
# 15834       NaN        12.0     NaN       NaN    NaN
# 15951       NaN        12.0     NaN       NaN    NaN
#
#                                              description  \
# 384    Караоке песни исполнителя Ирина Аллегрова. Поч...
# 385    С помощью Google Диск можно хранить, передават...
# 479    Караоке песни группы Фабрика. Почувствуйте себ...
# 525    В свое время в мире происходит по-настоящему ф...
# 618    Российский специалист по тайм-менджменту Глеб ...
# ...                                                  ...
# 15711  Создатель канала по прозвищу Тагс посвящает ко...
# 15770  Караоке песни исполнителя Светлана Лобода. Поч...
# 15790  Для поддержания формы и красоты ног можно восп...
# 15834  Ведущий своего канала делает обзор различных с...
# 15951  Автор проекта работает инженером-таксатором на...
#
#                                                 keywords release_year_cat
# 384           Ирина, Аллегрова, -, караоке, 2019, Россия        2010_2020
# 385               Google, Диск, Знакомство, 2020, Россия         2020_inf
# 479                    Фабрика, -, караоке, 2020, Россия         2020_inf
# 525                       Встречи, учеными, 2016, Россия        2010_2020
# 618    Глеб, Архангельский, Тайм-менеджмент, как, зас...         2020_inf
# ...                                                  ...              ...
# 15711                    TaGs, Play, Theme, 2010, Россия        2010_2020
# 15770        Светлана, Лобода, -, караоке, 2019, Украина        2010_2020
# 15790  Гибкость, ног, Безопасная, подготовка, к, шпаг...         2020_inf
# 15834                              Amitesh, 2014, Россия        2010_2020
# 15951                         Таёжник, ГИЛ, 2014, Россия        2010_2020
#
# [180 rows x 14 columns]

# %% [markdown]
# Преобразуем жанры: сгруппируем похожие, удалим все жанры, указывающие на географию фильма (есть отдельная фича), а так же несодержательные жанры и жанры, указывающие на то, фильм это или сериал (есть отдельная фича).

# %%
class GenrePreprocessor:
    def __init__(self, genres, frequency_threshold = 0.005):
        self.synonims = (
            ("мультфильмы", "мультфильм", "мультсериалы", "анимация", "русские мультфильмы", "западные мультфильмы"),
            ("мюзиклы", "мюзикл"),
            ("реалити", "реалити-шоу"),
            ("ток-шоу", "токшоу"),
            ("детские", "для самых маленьких", "для детей"),
            ("короткометражные", "короткий метр"),
            ("исторические", "историческое"),
            ("музыка", "музыкальные", "концерт"),
            (("детские", "музыка"), "детские песни"),
            ("для взрослых", "18+"),
            ("познавательные", "образование", "развитие"),
        )
        self.ban = set(["популярное", "фильм", "фильмы", "сериал", "сериалы", "фильмы hbo", "зарубежные", "русские", "советские", "полнометражные", "рекомендуем"])
        self.synonims = {g: genre_group[0] for genre_group in self.synonims for g in genre_group[1:]}

        # calculate genres statistics
        all_genres = [genre for sublist in genres for genre in self._filter_genres(sublist.split(', '))]
        genres_counts = Counter(all_genres)
        self.rare_genres = set([key for key, count in genres_counts.items() if count < frequency_threshold * len(genres)])
        # add rare genres to banned genres
        self.ban |= self.rare_genres
    
        # recalculate
        all_genres = [genre for sublist in genres for genre in self._filter_genres(sublist.split(', '))]
        self.genres_counts = Counter(all_genres)
        self.all_genres = set(all_genres)

        print(f'All genres:')
        pprint(sorted(self.all_genres))
        print(f'Num genres: {len(self.all_genres)}')
        pprint(self.genres_counts)

    def _filter_genres(self, genres: list[str]):
        final_genres = []
        for g in genres:
            g = self.synonims[g] if g in self.synonims.keys() else g
            if not isinstance(g, tuple):
                if g in self.ban:
                    continue
                final_genres.append(g)
            else:
                g = [x for x in g if x not in self.ban]
                final_genres.extend(g)
        return final_genres or ['no_genre']


    def preprocess_genres_str(self, s: str):
        genres = s.split(', ')
        return self._filter_genres(genres)

# %%
gp = GenrePreprocessor(items_df['genres'], 0.005)
# Out:
# All genres:
# ['no_genre',
#  'аниме',
#  'биография',
#  'боевики',
#  'военные',
#  'детективы',
#  'детские',
#  'для взрослых',
#  'документальное',
#  'драмы',
#  'исторические',
#  'комедии',
#  'короткометражные',
#  'криминал',
#  'мелодрамы',
#  'музыка',
#  'мультфильмы',
#  'мюзиклы',
#  'познавательные',
#  'приключения',
#  'про животных',
#  'развлекательные',
#  'семейное',
#  'спорт',
#  'триллеры',
#  'ужасы',
#  'фантастика',
#  'фитнес',
#  'фэнтези',
#  'хочу всё знать']
# Num genres: 30
# Counter({'драмы': 5431,
#          'комедии': 3858,
#          'мелодрамы': 2778,
#          'триллеры': 2418,
#          'приключения': 1877,
#          'боевики': 1820,
#          'документальное': 1339,
#          'криминал': 1306,
#          'детективы': 1224,
#          'мультфильмы': 1210,
#          'фантастика': 1118,
#          'семейное': 1089,
#          'ужасы': 1033,
#          'фэнтези': 999,
#          'детские': 998,
#          'военные': 626,
#          'исторические': 549,
#          'для взрослых': 494,
#          'биография': 469,
#          'фитнес': 382,
#          'no_genre': 373,
#          'музыка': 371,
#          'спорт': 308,
#          'познавательные': 254,
#          'короткометражные': 180,
#          'мюзиклы': 169,
#          'развлекательные': 97,
#          'про животных': 96,
#          'хочу всё знать': 95,
#          'аниме': 83})

# %%
items_df['genres'] = items_df['genres'].apply(gp.preprocess_genres_str)

# %% [markdown]
# #### countries

# %%
items_df['countries'].value_counts()
# Out:
# countries
# Россия                                  4237
# США                                     4090
# СССР                                    1401
# Франция                                 1158
# Великобритания                           718
#                                         ...
# Великобритания, Франция, Австралия         1
# США, Германия, Чехия, Великобритания       1
# Германия, США, Нидерланды                  1
# США, Франция, Канада                       1
# США, Германия, Франция, Испания            1
# Name: count, Length: 687, dtype: int64

# %%
items_df[items_df.countries.isna()].shape
# Out:
# (37, 14)

# %%
items_df[items_df.countries.isna()].head()
# Out:
#       item_id content_type                              title title_orig  \
# 374     10656       series                медитации для жизни       None
# 375     11526       series                 психология питания       None
# 573        63       series                  пробуди силу духа       None
# 750     11551       series               растяжка для кaждого       None
# 1960    16014       series  работа с телом для молодости лица       None
#
#                genres countries  for_kids  age_rating studios directors  \
# 374          [фитнес]       NaN       NaN         6.0     NaN       NaN
# 375   [фитнес, спорт]       NaN       NaN         6.0     NaN       NaN
# 573   [фитнес, спорт]       NaN       NaN         6.0     NaN       NaN
# 750   [фитнес, спорт]       NaN       NaN         6.0     NaN       NaN
# 1960  [фитнес, спорт]       NaN       NaN         6.0     NaN       NaN
#
#      actors                                        description  \
# 374     NaN  В этой программе собраны 3 базовых урока, на к...
# 375     NaN  В программе от Motify ты узнаешь о психологиче...
# 573     NaN  Три коротких и энергичных класса Кундалини йог...
# 750     NaN  Программа от Motify поможет вам почувствовать ...
# 1960    NaN  Программа от Motify направлена на работу с тел...
#
#                                                keywords release_year_cat
# 374   Медитации, для, жизни, спорт-фитнес, спорт-тре...         2020_inf
# 375                                 Психология, питания         2020_inf
# 573   Пробуди, силу, Духа, 2021, спорт-фитнес, спорт...         2020_inf
# 750                              Растяжка, для, кaждого         2020_inf
# 1960                Работа, телом, для, молодости, лица         2020_inf

# %%
items_df.loc[items_df.countries.isna(), 'countries'] = 'Россия'

# %%
items_df['countries'] = items_df['countries'].str.lower()
items_df['countries'] = items_df['countries'].apply(lambda x: ', '.join(sorted(list(set(x.split(', '))))))

# %%
items_df.countries.value_counts().head(10)
# Out:
# countries
# россия                 4274
# сша                    4090
# ссср                   1401
# франция                1158
# великобритания          718
# украина                 340
# италия                  256
# канада                  233
# республика корея        230
# великобритания, сша     193
# Name: count, dtype: int64

# %%
items_df['countries'] = items_df['countries'].astype('category')

# %% [markdown]
# #### for_kids

# %%
items_df['for_kids'].value_counts()
# Out:
# for_kids
# 0.0    452
# 1.0    114
# Name: count, dtype: int64

# %%
items_df['for_kids'] = items_df['for_kids'].fillna(0)
items_df['for_kids'] = items_df['for_kids'].astype('bool')

# %%
items_df['for_kids'].value_counts()
# Out:
# for_kids
# False    15849
# True       114
# Name: count, dtype: int64

# %% [markdown]
# #### age_rating

# %%
items_df.age_rating.value_counts()
# Out:
# age_rating
# 16.0    5729
# 12.0    4147
# 18.0    2547
# 6.0     1538
# 0.0     1518
# 21.0     482
# Name: count, dtype: int64

# %%
items_df[items_df.age_rating.isna()]
# Out:
#        item_id content_type             title title_orig  \
# 8297      6316       series  машины-помощники       None
# 12352    14409       series            бибабу       None
#
#                                                   genres countries  for_kids  \
# 8297   [детские, хочу всё знать, мультфильмы, познава...    россия     False
# 12352  [детские, хочу всё знать, мультфильмы, познава...    россия     False
#
#        age_rating studios directors actors  \
# 8297          NaN     NaN       NaN    NaN
# 12352         NaN     NaN       NaN    NaN
#
#                                              description  \
# 8297   Маленькие мальчики всего мира любят играть в м...
# 12352  В сказочное подводное царство приглашают мален...
#
#                                                 keywords release_year_cat
# 8297   Машины-помощники, 2017, Россия, работа, преодо...        2010_2020
# 12352  друзья, магия и волшебство, рыбы, моря и океан...        2010_2020

# %%
items_df.loc[items_df.age_rating.isna(), 'age_rating'] = 0

# %%
items_df['age_rating'] = items_df['age_rating'].astype(int).astype('category')

# %%
items_df
# Out:
#        item_id content_type                 title      title_orig  \
# 0        10711         film        поговори с ней  Hable con ella
# 1         2508         film           голые перцы    Search Party
# 2        10716         film      тактическая сила  Tactical Force
# 3         7868         film                45 лет        45 Years
# 4        16268         film  все решает мгновение            None
# ...        ...          ...                   ...             ...
# 15958     6443       series         полярный круг   Arctic Circle
# 15959     2367       series               надежда            None
# 15960    10632       series                сговор          Hassel
# 15961     4538       series          среди камней      Darklands
# 15962     3206       series                  гоша            None
#
#                                        genres            countries  for_kids  \
# 0               [драмы, детективы, мелодрамы]              испания     False
# 1                      [приключения, комедии]                  сша     False
# 2      [криминал, триллеры, боевики, комедии]               канада     False
# 3                          [драмы, мелодрамы]       великобритания     False
# 4                   [драмы, спорт, мелодрамы]                 ссср     False
# ...                                       ...                  ...       ...
# 15958             [драмы, триллеры, криминал]  германия, финляндия     False
# 15959                        [драмы, боевики]               россия     False
# 15960             [драмы, триллеры, криминал]               россия     False
# 15961                [драмы, спорт, криминал]               россия     False
# 15962                               [комедии]               россия     False
#
#       age_rating   studios                              directors  \
# 0             16       NaN                       Педро Альмодовар
# 1             16       NaN                         Скот Армстронг
# 2             16       NaN                       Адам П. Калтраро
# 3             16       NaN                              Эндрю Хэй
# 4             12  Ленфильм                       Виктор Садовский
# ...          ...       ...                                    ...
# 15958         16       NaN                          Ханну Салонен
# 15959         18       NaN                         Елена Хазанова
# 15960         18       NaN  Эшреф Рейбрук, Амир Камдин, Эрик Эгер
# 15961         18       NaN          Марк О’Коннор, Конор МакМахон
# 15962         16       NaN                         Михаил Миронов
#
#                                                   actors  \
# 0      Адольфо Фернандес, Ана Фернандес, Дарио Гранди...
# 1      Адам Палли, Брайан Хаски, Дж.Б. Смув, Джейсон ...
# 2      Адриан Холмс, Даррен Шалави, Джерри Вассерман,...
# 3      Александра Риддлстон-Барретт, Джеральдин Джейм...
# 4      Александр Абдулов, Александр Демьяненко, Алекс...
# ...                                                  ...
# 15958  Иина Куустонен, Максимилиан Брюкнер, Пихла Вии...
# 15959  Виктория Исакова, Александр Кузьмин, Алексей М...
# 15960  Ола Рапас, Алиетт Офейм, Уильма Лиден, Шанти Р...
# 15961  Дэйн Уайт О’Хара, Томас Кэйн-Бирн, Джудит Родд...
# 15962                 Мкртыч Арзуманян, Виктория Рунцова
#
#                                              description  \
# 0      Мелодрама легендарного Педро Альмодовара «Пого...
# 1      Уморительная современная комедия на популярную...
# 2      Профессиональный рестлер Стив Остин («Все или ...
# 3      Шарлотта Рэмплинг, Том Кортни, Джеральдин Джей...
# 4      Расчетливая чаровница из советского кинохита «...
# ...                                                  ...
# 15958  Во время погони за браконьерами по лесу, сотру...
# 15959  Оригинальный киносериал от создателей «Бывших»...
# 15960  Криминальная драма по мотивам романов о шведск...
# 15961  Семнадцатилетний Дэмиен мечтает вырваться за п...
# 15962  Добродушный Гоша не может выйти из дома, чтобы...
#
#                                                 keywords release_year_cat
# 0      Поговори, ней, 2002, Испания, друзья, любовь, ...        2000_2010
# 1      Голые, перцы, 2014, США, друзья, свадьбы, прео...        2010_2020
# 2      Тактическая, сила, 2011, Канада, бандиты, ганг...        2010_2020
# 3      45, лет, 2015, Великобритания, брак, жизнь, лю...        2010_2020
# 4      Все, решает, мгновение, 1978, СССР, сильные, ж...        1970_1980
# ...                                                  ...              ...
# 15958  убийство, вирус, расследование преступления, н...        2010_2020
# 15959                              Надежда, 2020, Россия         2020_inf
# 15960                               Сговор, 2017, Россия        2010_2020
# 15961                        Среди, камней, 2019, Россия        2010_2020
# 15962                                 Гоша, 2019, Россия        2010_2020
#
# [15963 rows x 14 columns]

# %% [markdown]
# #### studios

# %%
items_df['studios'] = items_df['studios'].fillna('Unknown')

# %%
items_df['studios'] = items_df['studios'].str.lower()
items_df['studios'] = items_df['studios'].apply(lambda x: ', '.join(sorted(list(set(x.split(', '))))))

# %%
# all_studios = []
# for studio in items_df['studios'].unique():
#     all_studios.extend(studio.split(', '))
# len(all_studios)

# %%
items_df['studios'] = items_df['studios'].astype('category')

# %% [markdown]
# #### directors

# %%
items_df['directors'] = items_df['directors'].fillna('Unknown')

# %%
items_df['directors'] = items_df['directors'].str.lower()

# %%
items_df['directors'] = items_df['directors'].astype('category')

# %% [markdown]
# #### actors

# %%
items_df['actors'] = items_df['actors'].fillna('Unknown')

# %%
items_df['actors'] = items_df['actors'].astype('category')

# %% [markdown]
# #### keywords

# %%
items_df['keywords'].head()
# Out:
# 0    Поговори, ней, 2002, Испания, друзья, любовь, ...
# 1    Голые, перцы, 2014, США, друзья, свадьбы, прео...
# 2    Тактическая, сила, 2011, Канада, бандиты, ганг...
# 3    45, лет, 2015, Великобритания, брак, жизнь, лю...
# 4    Все, решает, мгновение, 1978, СССР, сильные, ж...
# Name: keywords, dtype: object

# %% [markdown]
# Если планируется использовать - можно, например, заполнить пропуски копипастой из других фич

# %%
items_df['keywords'] = items_df['keywords'].fillna('Unknown')

# %%
items_df['keywords'] = items_df['keywords'].astype('category')

# %% [markdown]
# #### description

# %%
items_df['description'] = items_df['description'].fillna('-')

# %% [markdown]
# #### Duplicates check

# %%
items_df.duplicated(subset=['item_id'], keep=False).sum()
# Out:
# np.int64(0)

# %%
items_df.duplicated(subset=['title']).sum()
# Out:
# np.int64(687)

# %%
items_df[items_df.duplicated(subset=['content_type', 'countries', 'title', 'directors'], keep=False)].sort_values('title')[['content_type', 'title', 'countries', 'for_kids', 'directors']].head()
# Out:
#       content_type                title   countries  for_kids     directors
# 7333          film  пираты по соседству  нидерланды     False  пим ван хёве
# 12757         film  пираты по соседству  нидерланды     False  пим ван хёве

# %%
items_df.duplicated(subset=['content_type', 'countries', 'title', 'directors'], keep=False).sum()
# Out:
# np.int64(2)

# %% [markdown]
# ### Result

# %%
items_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15963 entries, 0 to 15962
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_id           15963 non-null  int64
#  1   content_type      15963 non-null  category
#  2   title             15963 non-null  object
#  3   title_orig        15963 non-null  object
#  4   genres            15963 non-null  object
#  5   countries         15963 non-null  category
#  6   for_kids          15963 non-null  bool
#  7   age_rating        15963 non-null  category
#  8   studios           15963 non-null  category
#  9   directors         15963 non-null  category
#  10  actors            15963 non-null  category
#  11  description       15963 non-null  object
#  12  keywords          15963 non-null  category
#  13  release_year_cat  15963 non-null  category
# dtypes: bool(1), category(8), int64(1), object(4)
# memory usage: 2.4+ MB

# %% [markdown]
# ## Interactions

# %%
interactions_df.head()
# Out:
#    user_id  item_id last_watch_dt  total_dur  watched_pct
# 0   176549     9506    2021-05-11       4250         72.0
# 1   699317     1659    2021-05-29       8317        100.0
# 2   656683     7107    2021-05-09         10          0.0
# 3   864613     7638    2021-07-05      14483        100.0
# 4   964868     9506    2021-04-30       6725        100.0

# %%
interactions_df.shape
# Out:
# (5476251, 5)

# %%
interactions_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5476251 entries, 0 to 5476250
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   user_id        int64
#  1   item_id        int64
#  2   last_watch_dt  datetime64[ns]
#  3   total_dur      int64
#  4   watched_pct    float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 208.9 MB

# %%
interactions_df.nunique()
# Out:
# user_id          962179
# item_id           15706
# last_watch_dt       163
# total_dur        129788
# watched_pct         101
# dtype: int64

# %%
print(f'Data date range: {interactions_df.last_watch_dt.min().date()} - {interactions_df.last_watch_dt.max().date()}')
# Out:
# Data date range: 2021-03-13 - 2021-08-22

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### watched_pct

# %%
interactions_df.watched_pct.max()
# Out:
# np.float64(100.0)

# %%
interactions_df.watched_pct.min()
# Out:
# np.float64(0.0)

# %%
interactions_df['watched_pct'] = interactions_df['watched_pct'].astype(pd.Int8Dtype())

# %%
interactions_df['watched_pct'] = interactions_df['watched_pct'].fillna(0)

# %%
interactions_df['watched_pct'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### total_dur

# %%
interactions_df['total_dur'].hist()
# Out:
# <Axes: >

# %%
interactions_df[interactions_df['total_dur'] > 200000].shape
# Out:
# (16042, 5)

# %%
interactions_df[interactions_df['total_dur'] < 200000].total_dur.hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# #### last_watch_dt

# %%
interactions_df['last_watch_dt'] = pd.to_datetime(interactions_df['last_watch_dt'])

# %%
interactions_df['last_watch_dt'].hist(bins=50);

# %% [markdown]
# #### Duplicates check

# %%
interactions_df.duplicated(subset=['user_id', 'item_id'], keep=False).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Result

# %%
interactions_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5476251 entries, 0 to 5476250
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   user_id        int64
#  1   item_id        int64
#  2   last_watch_dt  datetime64[ns]
#  3   total_dur      int64
#  4   watched_pct    Int8
# dtypes: Int8(1), datetime64[ns](1), int64(3)
# memory usage: 177.6 MB

# %% [markdown]
# # Some stats

# %%
interaction_users = interactions_df['user_id'].unique()

common_users = len(np.intersect1d(interaction_users, users_df['user_id']))
users_only_in_interaction = len(np.setdiff1d(interaction_users, users_df['user_id']))
users_only_features = len(np.setdiff1d(users_df['user_id'], interaction_users))
total_users = common_users + users_only_in_interaction + users_only_features

print(f'Кол-во пользователей всего                         {total_users}')
print(f'Кол-во пользователей c взаимодействиями и фичами   {common_users} ({common_users / total_users * 100:.2f}%)')
print(f'Кол-во пользователей только c взаимодействиями     {users_only_in_interaction} ({users_only_in_interaction / total_users * 100:.2f}%)')
print(f'Кол-во пользователей только c фичами               {users_only_features} ({users_only_features / total_users * 100:.2f}%)')
# Out:
# Кол-во пользователей всего                         1058088
# Кол-во пользователей c взаимодействиями и фичами   744288 (70.34%)
# Кол-во пользователей только c взаимодействиями     217891 (20.59%)
# Кол-во пользователей только c фичами               95909 (9.06%)

# %%
interaction_items = interactions_df['item_id'].unique()

common_items = len(np.intersect1d(interaction_items, items_df['item_id']))
items_only_in_interaction = len(np.setdiff1d(interaction_items, items_df['item_id']))
items_only_features = len(np.setdiff1d(items_df['item_id'], interaction_items))
total_items = common_items + items_only_in_interaction + items_only_features
print(f'Кол-во объектов всего                         {total_items}')
print(f'Кол-во объектов c взаимодействиями и фичами   {common_items} ({common_items / total_items * 100:.2f}%)')
print(f'Кол-во объектов только c взаимодействиями     {items_only_in_interaction} ({items_only_in_interaction / total_items * 100:.2f}%)')
print(f'Кол-во объектов только c фичами               {items_only_features} ({items_only_features / total_items * 100:.2f}%)')
# Out:
# Кол-во объектов всего                         15963
# Кол-во объектов c взаимодействиями и фичами   15706 (98.39%)
# Кол-во объектов только c взаимодействиями     0 (0.00%)
# Кол-во объектов только c фичами               257 (1.61%)

# %% [markdown]
# График количества польователей от даты

# %%
interactions_df_users_count = interactions_df.groupby("last_watch_dt").agg({'user_id': pd.Series.nunique}).reset_index().sort_values('last_watch_dt')
sns.lineplot(data=interactions_df_users_count, x="last_watch_dt", y="user_id");

# %% [markdown]
# График количества уникальных пользователей от даты

# %%
interactions_df_unique_users_count = []
unique_users = set()

for date in sorted(interactions_df.last_watch_dt.unique()):
    date_unique_users = interactions_df[interactions_df.last_watch_dt == date].user_id.unique()
    interactions_df_unique_users_count.append((date, len(set(date_unique_users) - unique_users)))
    unique_users = unique_users.union(set(date_unique_users))

# %%
sns.lineplot(data=pd.DataFrame(interactions_df_unique_users_count, columns=['date', 'count']), x="date", y="count")
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %% [markdown]
# Ага, очевидно, что каждый день есть у нас есть новые, "холодные" пользователи
# Это необходимо учесть в модели и по хорошему - придумать, что с ними делать

# %% [markdown]
# Посмотрим на обьекты

# %%
interactions_df_items_count = interactions_df.groupby("last_watch_dt").agg({'item_id': pd.Series.nunique}).reset_index().sort_values('last_watch_dt')
sns.lineplot(data=interactions_df_items_count, x="last_watch_dt", y="item_id");

# %%
interactions_df_unique_items_count = []
unique_items = set()

for date in sorted(interactions_df.last_watch_dt.unique()):
    date_unique_items = interactions_df[interactions_df.last_watch_dt == date].item_id.unique()
    interactions_df_unique_items_count.append((date, len(set(date_unique_items) - unique_items)))
    unique_items = unique_items.union(set(date_unique_items))
    
interactions_df_unique_items_count = pd.DataFrame(interactions_df_unique_items_count, columns=['date', 'count'])

# %%
sns.lineplot(data=interactions_df_unique_items_count, x="date", y="count")
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %%
sns.lineplot(data=interactions_df_unique_items_count[interactions_df_unique_items_count.date > '2021-04-01'], x="date", y="count")
# Out:
# <Axes: xlabel='date', ylabel='count'>

# %% [markdown]
# "Холодные" объекты тоже есть, но их явно меньше

# %% [markdown]
# # Сохранение

# %%
users_df.to_csv(osp.join(DATA_PATH, 'users_processed.csv'), index=False)
items_df.to_csv(osp.join(DATA_PATH, 'items_processed.csv'), index=False)
interactions_df.to_csv(osp.join(DATA_PATH, 'interactions_processed.csv'), index=False)
